# %%
#requiremnets
import pandas
import json

#import pyscrape.py
import pyscrape

# %%
#running pyscrape.py main method
#will print every team member for testing purposes 
#output will be written to file players.json
pyscrape.main()
# Out:
# 0 Sam DeSantis
# 1 Madison Schultz
# 2 Sydney Spruill
# 3 Ru Mucherera
# 4 Bridgette Andrzejewski
# 5 Maya Worth
# 6 Taylor Otto
# 7 Annie Kingman
# 8 Abby Elinsky
# 9 Frances Reuland
# 10 Joanna Boyles
# 11 Emily Fox
# 12 Jessie Scarpa
# 13 Samantha Leshnak
# 14 Morgan Goff
# 15 Zoe Redei
# 16 Julia Ashley
# 17 Alea Hyatt
# 18 Megan Buckingham
# 19 Alessia Russo
# 20 Kate Morris
# 21 Miah Araba
# 22 Abby Staker
# 23 Lotte Wubben-Moy
# 24 Kasey Parker
# 28 Maggie Bill
# 29 Dorian Bailey
# 30 Brooke Bingham
# 32 Nicole Crutchfield
# 47 Alex Kimball
# 49 Cannon Clough
# 99 Laura Sparling

# %%
#save instance of file to variable data
#make dataframe using pandas library
data = json.load(open('players.json'))
df=pandas.DataFrame(data)

# %%
df
# Out:
#                                                           0  \
# bio       \r\n                        Biography\r\n     ...
# height                                                  5-7
# hometown                     Hickory, N.C. / Saint Stephens
# href                               /roster.aspx?rp_id=13084
# img       /images/2017/8/4/DeSantis_Sam_ws_82.jpg?width=300
# name                                           Sam DeSantis
# num                                                       0
# position                                         Goalkeeper
# stats                                                    {}
# year                                                    So.
#
#                                                           1  \
# bio       \r\n                        Biography\r\n     ...
# height                                                  5-4
# hometown                   Edmonds, Wash. / Edmonds-Woodway
# href                               /roster.aspx?rp_id=13077
# ...

# %%
#transpose will swap the axis of the dataframe 
df.transpose()
# Out:
#                                                   bio height  \
# 0   \r\n                        Biography\r\n     ...    5-7
# 1   \r\n                        Biography\r\n     ...    5-4
# 10  \r\n                        Biography\r\n     ...    5-8
# 11  \r\n                        Biography\r\n     ...    5-5
# 12  \r\n                        Biography\r\n     ...    5-7
# 13  \r\n                        Biography\r\n     ...   5-11
# 14  \r\n                        Biography\r\n     ...    5-8
# 15  \r\n                        Biography\r\n     ...    5-4
# 16  \r\n                        Biography\r\n     ...    5-8
# 17  \r\n                        Biography\r\n     ...    5-9
# 18  \r\n                        Biography\r\n     ...    5-5
# 19  \r\n                        Biography\r\n     ...    5-9
# 2   \r\n                        Biography\r\n     ...    5-5
# 20  \r\n                        Biography\r\n     ...    5-6
# ...
